# %% [markdown]
# # DAY35 Threshold Sensitivity — Research Only
# This notebook visualizes committed DAY35 CSV evidence. It does not access benchmark-locked truth.

# %%
from pathlib import Path
import pandas as pd
ROOT = Path("qa-validation/evidence")
sweep = pd.read_csv(ROOT / "day35-threshold-sensitivity-results-v0.1.csv")
robust = pd.read_csv(ROOT / "day35-robustness-by-fs-window-v0.1.csv")
sweep.groupby("family_id")["weighted_error"].min()

# %% [markdown]
# ## Interpretation guard
# Minimum weighted error identifies a **research heuristic operating point**, not a clinical/site threshold. Locked evaluation data remain unused.
